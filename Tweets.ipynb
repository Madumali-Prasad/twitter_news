# %% [markdown]
# <a href="https://colab.research.google.com/github/Madumali-Prasad/twitter_news/blob/main/Tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q snscrape==0.3.4

# %%
import os
import pandas as pd
from datetime import date

# %%
today = date.today()
end_date = today

# %%
search_term = 'BBC News (World)', 'Ada Derana'
from_date = '2019-01-01'

# %%
os.system(f"snscrape --since {from_date} twitter-search '{search_term} until:{end_date}' > result-tweets.csv")
if os.stat("result-tweets.csv").st_size == 0:
  counter = 0
else:
  df = pd.read_csv('result-tweets.csv', names=['tweets'])
  counter = df.size

print('Number Of Tweets : '+ str(counter))
# Out:
# Number Of Tweets : 39262

# %%
max_results = 500

# %%
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > extracted-tweets.txt"
os.system(extracted_tweets)
if os.stat("extracted-tweets.csv").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('extracted-tweets.csv', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# (0, '\'@BernieSpofforth @Fox_Claire @BBCNews They thrive off mass hysteria. \\nTHE CHINAFICATION OF THE WESTERN WORLD\\nAre you willing to sell yourself and your children to the State in order to keep everyone “safe?"\\nhttps://t.co/lL7WUtdoXP\'')
# (1, "'This I my country")
# (2, "'Hawaii Geopolitical News: BBC News - World https://t.co/rLPTdBNLl1'")
# (3, "'@CalanthaTXBlue BBC World News is still pure news. No spin")
# (4, "'@BernieSpofforth Using the oldest trope around (Africans=diseased)")
# (5, "@WithyGrove Right now it is about #nazism\\nperpetrated by #BigPharma\\nin BED with Imperial College of #London that imposed #lockdown &amp; #vaccine DOCTRINE to the world\\nand NOT French #colonialism !!\\nDON'T CONFUSE your readers PLEASE !!\\nOUTRAGEOUS !!\\n#Manifs27Novembre @BBCWorld @BBCNews @BBC @UN")
# (6, "Banksy-inspired NFT drives 'seismic' change in art world - BBC News https://t.co/UuH0UTe5SQ")
# ...

# %%
user_name = "BBC News (World)", "Ada Derana"
user_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-user '{user_name} until:{end_date}' > user-tweets.txt"
os.system(user_tweets)
if os.stat("user-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('user-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# ('\'"At times of crisis', ' reliable news and information from Public Service Broadcasters is more important than ever.  \\n\\nMy sincere thanks to those who defend media freedom around the world."  - Tony Hall.\\n \\n#WPFD2020 | @EBU_HQ \\n\\nhttps://t.co/MjERVeTsTw\'')
# ("'Veles", ' Macedonia')
